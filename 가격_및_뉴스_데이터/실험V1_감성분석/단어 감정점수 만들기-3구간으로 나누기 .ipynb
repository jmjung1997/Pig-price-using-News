# %%
import pandas as pd
import numpy as np
import sklearn as scikit_learn
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from konlpy.tag import Okt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import re
import urllib.request
# import mecab
from tqdm import tqdm
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import os

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df=pd.read_excel('./sentiment_data/all_data.xlsx')

# %%
df_sorted = df.sort_values('News_sentiment_AVG', ascending=True)

# %%
df_sorted
# Out:
#                                                   News  label     가격등락비율  \
# 90   ['한강', '한강', '이남', '김포', '아프리카', '열병', 'ASF', ...      2 -44.679075
# 101  ['ASF', 'ASF', '비', '발생', '지역', '경기', '경기', '북...      2 -23.308938
# 195  ['강원도', '강원도', '정선', '강원도', '정선', '야생', '강원도',...      2 -18.784132
# 197  ['한', '혁신', '센터', '한', '혁신', '센터', '평균', '한', ...      2  -6.404112
# 91   ['최근', '최근', '아프리카', '열병', 'ASF', '이', '확산', '...      2 -23.378273
# 28   ['한', '돈자', '조금', '하반기', '하반기', '안정', '위해', '위...      2 -15.621325
# 162  ['축산', '관련', '단체', '협의', '회', '도축', '세', '도축',...      2 -13.546398
# 12   ['ASF', 'ASF', '발병', 'ASF', '발병', '가능성', 'ASF'...      2  -7.339718
# 40   ['돼지고기', '돼지고기', '시장', '원료', '육', '햄', '소시지', ...      2  -9.748006
# 184  ['제', '한', '협회장', '한', '협회장', '선거', '개최', '한',...      2  -5.194040
# 87   ['가정', '가정', '내', '소비', '소비', '하다', '돼지고기', '점...      2 -12.920098
# 6                                                   []      2  -8.153108
# ...

# %%
import numpy as np
from sklearn.metrics import accuracy_score

def find_threshold(y_true, y_pred):
    # 예측값을 기준으로 오름차순으로 정렬
    sorted_pred = np.sort(y_pred)
    thresholds = sorted_pred
    accuracies = []

    for threshold in thresholds:
        # 임계값을 기준으로 예측값을 0 또는 1로 이진 분류
        y_pred_class = (y_pred >= threshold).astype(int)
        # 이진 분류한 결과에 대해 실제값과 비교하여 정확도 계산
        accuracy = accuracy_score(y_true, y_pred_class)
        accuracies.append(accuracy)
        
    # 가장 높은 정확도를 갖는 임계값 반환
    best_threshold = thresholds[np.argmax(accuracies)]
    return best_threshold

# %%
find_threshold(df['News_sentiment_AVG'],)
