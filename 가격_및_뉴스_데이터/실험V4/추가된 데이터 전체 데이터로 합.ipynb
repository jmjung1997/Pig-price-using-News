# %%
import pandas as pd

# %%
df= pd.read_csv('./V4_data/뉴스기사_뉴스감정점수.csv',encoding="utf-8")
df_add=pd.read_csv('./V4_data/newsnew_sentiment.csv',encoding="utf-8")

# %%
df.isnull().sum()
# Out:
# theme            0
# datetime         0
# title            0
# new_content      0
# sentiment      126
# dtype: int64

# %%
df_add
# Out:
#       theme    datetime                             title  \
# 0      축산신문  2017-12-13           “정산방식 전환돼도 농가 수취가 변함없게”
# 1      축산신문  2017-12-13  내년 한돈자조금 어떻게 쓰여지나 / 예비비·운영비·기타비용
# 2    오늘의 뉴스  2017-12-14         ‘박피 도축 중단’ 예정대로 실시(12/14)
# 3    오늘의 뉴스  2017-12-14          내년 동물복지 축산업 적극 유도(12/14)
# 4    오늘의 뉴스  2017-12-14          농축산부-환경부 정책 협력 강화(12/14)
# ..      ...         ...                               ...
# 148  오늘의 뉴스  2023-01-14                 한돈자조금, 물가안정‧소비 주력
# 149  오늘의 뉴스  2023-01-14             “과학 접목해 방역 효율 높이겠습니다”
# 150  오늘의 뉴스  2023-01-14                 농협, 한국형 종돈 전국에 보급
# 151  오늘의 뉴스  2023-01-14              한돈협, 새해 비전 '삼강' '삼고'
# 152  오늘의 뉴스  2023-01-26         한돈, 돈육 최대 수입국 中 만리장성 못 넘나
#
#                                            new_content  sentiment
# 0    정부가 박피도축 중단을 계기로 돼지가격의 등급정산제 정착을 독려하고 나섰다. 농림축...  -0.200000
# 1    내년에만 30억원 예상…지침 따라 운용 적립 한도 전체 예산 1/2 넘어선 안돼 운...   0.052632
# 2    ‘박피 도축 중단’ 예정대로 실시 정부 등 협의 통해 중단 재확인 박피 가격 未 고...  -0.500000
# ...

# %%
df
# Out:
#      theme    datetime                             title  \
# 0     축산신문  2017-12-13           “정산방식 전환돼도 농가 수취가 변함없게”
# 1     축산신문  2017-12-13  내년 한돈자조금 어떻게 쓰여지나 / 예비비·운영비·기타비용
# 2     축산신문  2017-12-15                   등급정산제 조기정착 ‘올인’
# 3     축산신문  2017-12-15             “한돈산업, 高생산비·低생산성 넘어야”
# 4     축산신문  2017-12-21   한돈팜스 ’16년 전산성적·’18년 수급전망…주요 내용은
# ...    ...         ...                               ...
# 4402  한돈뉴스  2022-01-10           방역지원본부, 경남도본부 동북부사무소 개소
# 4403  한돈뉴스  2022-01-10               대규모 양돈장 정화시설 설치 의무화
# 4404  한돈뉴스  2022-01-10               돼지고기도 온라인으로 구입할수 있다
# 4405  한돈뉴스  2022-01-10         19~20일 ‘농업전망 2022’ 온라인 개최
# 4406  한돈뉴스  2022-01-10      지난해 돼지고기 33만2757톤 수입…7.2% 증가
#
#                                             new_content  sentiment
# 0     \n정부가 박피도축 중단을 계기로 돼지가격의 등급정산제 정착을 독려하고 나섰다.\n...        NaN
# 1     \n내년에만 30억원 예상…지침 따라 운용\n적립 한도 전체 예산 1/2 넘어선 안...        NaN
# 2     대한한돈협회(회장 하태식)가 등급정산제 조기 정착에 올인하고 있다.\n잇따른 성명을...        NaN
# ...
