# %%
import pandas as pd
import numpy as np
import sklearn as scikit_learn
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from konlpy.tag import Okt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import re
import urllib.request
# import mecab
from tqdm import tqdm
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import os
# Out:
# C:\Users\jaemin\Anaconda3\envs\py38\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\jaemin\Anaconda3\envs\py38\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\jaemin\Anaconda3\envs\py38\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_price=pd.read_excel('../data/가격데이터_증감비교_라벨링_가격등락비율.xlsx')

# %%
df_news_list=[]
for i in range(208):
    with open('../data/data/stem_list{}.txt'.format(i),'r',encoding='UTF-8') as f:
        lines = f.readlines()
        df_news_list.append(lines)

# %%
df_news_list[150]
# Out:
# ['정부 ASF ASF 피해 ASF 피해 농가 대한 대한 재입 식 재개 또한 또한 경기 강원 강원 개 강원 개 시 군 처음 ASF 중점 방역 관리 지구 지정 아프리카 열병 아프리카 열병 중앙 사고 수습 본부 긴급 행동지침 SOP 과 전문가 과 전문가 의견 검토 지난 지난 지난 양돈 농장 아프리카 열병 발생 잠정 잠정 중단 잠정 중단 하다 경기 강원 양돈 농장 강원 양돈 농장 강원 양돈 농장 재입 식 강원 양돈 농장 재입 식 절차 다시 다시 추진 기존 기존 재입 식 기존 재입 식 평가 양돈 농장 입 식 신고 입 식 신고 및 입 식 신고 및 입 식 신고 및 공급 입 식 신고 및 공급 계약 상황 중 재입 식이 재입 식이 가능하다 수 재입 식이 가능하다 수 있다 것 전망 또한 아프리카 열병 또한 아프리카 열병 발생 사 육 멧돼지 시 군 시 군 인접 시 군 인접 시 군 총 개 총 개 시 군 중점 방역 관리 지구 로 지정 방역 관리 강화 키로 개 개 시 군 ASF 발생 ASF 발생 개 ASF 발생 개 시 군 김포 강화 연천 파주 포천 화천 철원 양구 인제 고성 춘천 양돈 농장 호 과 인접 과 인접 개 과 인접 개 시 군 고양 양주 동두천 가평 남양주 홍천 양양 호 등 양돈 장 등 양돈 장 호가 등 양돈 장 호가 해당 중점 방역 관리 지구 내 중점 방역 관리 지구 내 양돈 농장 가지 가지 강화 가지 강화 되다 방역 시설 가지 강화 되다 방역 시설 기준 외부 울타리 방조 방충 망 폐 사체 폐 사체 보관 시설 내부 울타리 입 출하 대 방역 실 전 실 물품 반입 시설 물품 반입 시설 개 물품 반입 시설 개 항목 개월내 마련 이 관련 이 재욱 이 재욱 농림축산식품부 이 재욱 농림축산식품부 차관 오전 오전 개최 오전 개최 되다 가축 질병 오전 개최 되다 가축 질병 방역 상황 점검 영상 회의 오늘 경기 강원 개 시 살 처분 수 매 수 매 농장 수 매 농장 호의 수 매 농장 호의 재입 식 수 매 농장 호의 재입 식 절차 중점 방역 관리 지구 지자체 관내 관내 양돈 농장 내년 내년 전 실 등 전 실 등 가지 전 실 등 가지 강화 전 실 등 가지 강화 되다 방역 시설 차질 조치 당부 재입 식 재입 식 절차 접경 지역 야생 멧돼지 야생 멧돼지 ASF 지속 지속 발생 지자체 지자체 검역 본부 재입 식 농장 대한 청소 소독 분뇨 분뇨 처리 시설 시설 보완 시설 보완 실태 시설 보완 실태 점검 실시 강조 피해 농가 중점 방역 관리 지구 아프리카 열병 중앙 사고 수습 본부 긴급 행동지침 전문가 의견 양돈 농장 발생 중단 절차 추진 평가 입 식 신고 공급 계약 상황 재입 식이 인접 양돈 장 호가 해당 가지 기준 외부 울타리 방충 사체 보관 내부 출하 대 물품 반입 항목 개월내 관련 농림축산식품부 차관 오전 개최 가축 질병 점검 영상 회의 처분 호의 접경 지역 야생 검역 청소 처리 보완 실태']

# %% [markdown]
# ### embedding list 형태로 만들기

# %%
embedding_list=[]

for week_news in df_news_list:
    embedding_list.append(week_news[0])

vocab = list(set(w for doc in embedding_list for w in doc.split()))
vocab.sort()

# 총 문서의 수
N = len(embedding_list) 
print(N)
# Out:
# 208

# %%
# 단어 종류의 갯수
len(vocab)
# Out:
# 5366

# %%
day_news_list=[]
vocab_dic={}

# %%
for day_news in embedding_list:
    day_news_list.append(day_news.split())

# %%
for vocabulary in vocab:
    for i in range(len(day_news_list)):
        if str(vocabulary) in day_news_list[i]:
            if vocabulary in vocab_dic:
                vocab_dic[vocabulary] += 1
            else:
                vocab_dic[vocabulary] = 1

# %%
vocab_dic
# Out:
# {'A': 7,
#  'AI': 16,
#  'APVS': 2,
#  'ASF': 108,
#  'AT': 2,
#  'ATOM': 1,
#  'Animal': 1,
#  'B': 1,
#  'BMEL': 1,
#  'BSE': 1,
#  'Business': 1,
#  'C': 1,
#  'CCTV': 1,
#  'CIF': 1,
#  'CJ': 2,
#  'CME': 1,
#  'CPTPP': 2,
#  'CSF': 2,
#  'Center': 1,
#  'Chart': 1,
#  'CoV': 1,
#  'Consumer': 1,
#  'Control': 1,
#  'DB': 1,
#  'DMZ': 2,
#  'Diseases': 1,
#  'EU': 12,
#  'F': 4,
#  'FCR': 1,
#  'FMD': 4,
#  'FTA': 12,
#  'FVC': 1,
#  'GGP': 3,
#  'GO': 1,
#  'GP': 3,
#  'GPS': 2,
#  'GUN': 1,
#  'HACCP': 1,
#  'HMR': 1,
#  'ICT': 3,
#  'IMC': 1,
#  'JP': 1,
#  'JTBC': 1,
#  'KBS': 1,
#  'KSTAR': 1,
#  'L': 1,
#  'MC': 1,
#  'MOU': 6,
#  'MSY': 14,
#  'NH': 2,
#  'NSP': 3,
#  'NULL': 10,
#  'National': 1,
#  'Neisse': 1,
#  'O': 4,
#  'OIE': 6,
#  'P': 18,
#  'PC': 1,
#  'PCR': 2,
#  'PED': 14,
#  'PM': 2,
#  'PPL': 1,
#  'PRDC': 1,
#  'PRRS': 2,
#  'PSY': 8,
#  'Polymerase': 1,
#  'RFID': 1,
#  'SARS': 1,
#  'SBS': 1,
#  'SFEED': 1,
#  'SNS': 2,
#  'SOP': 10,
#  'SP': 1,
#  'SPS': 2,
#  'STC': 1,
#  'Spree': 1,
#  'TPP': 1,
#  'TV': 6,
#  'WTO': 2,
#  'YLD': 1,
#  'aT': 5,
#  'and': 1,
#  'chain': 1,
#  'for': 1,
#  'g': 13,
#  'kg': 24,
#  'km': 22,
#  'm': 11,
#  'mm': 3,
#  'n': 1,
#  'p': 2,
#  'r': 1,
#  'reaction': 1,
#  'to': 1,
#  '가가': 15,
#  '가격': 103,
#  '가결': 1,
#  '가계': 1,
#  '가계부': 1,
#  '가공': 36,
#  '가공업': 7,
#  '가공품': 16,
#  '가구': 9,
#  '가금': 1,
#  '가까이': 5,
#  '가깝다': 7,
#  '가늠': 2,
#  '가늠자': 1,
#  '가능': 8,
#  '가능성': 53,
#  '가능하다': 13,
#  '가다': 9,
#  '가도': 5,
#  '가동': 5,
#  '가드': 1,
#  '가득하다': 1,
#  '가뜩이나': 1,
#  '가량': 72,
#  '가령': 2,
#  '가로': 1,
#  '가르다': 8,
#  '가면': 1,
#  '가뭄': 3,
#  '가미': 1,
#  '가상': 2,
#  '가성': 2,
#  '가세': 1,
#  '가속': 8,
#  '가수': 7,
#  '가스': 3,
#  '가시': 1,
#  '가압류': 1,
#  '가야': 1,
#  '가열': 1,
#  '가용': 3,
#  '가운데': 85,
#  '가을': 5,
#  '가의': 2,
#  '가인': 1,
#  '가입': 2,
#  '가장': 75,
#  '가전': 2,
#  '가정': 30,
#  '가족': 5,
#  '가중': 6,
#  '가지': 17,
#  '가짜': 2,
#  '가축': 59,
#  '가치': 11,
#  '가치판단': 1,
#  '가칭': 2,
#  '가파르': 3,
#  '가평': 7,
#  '가평군': 2,
#  '가행위': 1,
#  '각': 19,
#  '각각': 71,
#  '각계': 1,
#  '각국': 1,
#  '각별': 2,
#  '각성': 1,
#  '각심': 1,
#  '각자': 1,
#  '각종': 16,
#  '각축': 1,
#  '각층': 1,
#  '각하': 1,
#  '간': 35,
#  '간격': 1,
#  '간담': 9,
#  '간략': 1,
#  '간문제': 2,
#  '간부': 1,
#  '간선': 1,
#  '간섭': 1,
#  '간소화': 4,
#  '간의': 2,
#  '간이': 1,
#  '간접': 1,
#  '간편식': 12,
#  '갈등': 1,
#  '갈말읍': 1,
#  '갈비': 11,
#  '갈비찜': 1,
#  '갈수록': 8,
#  '감': 12,
#  '감금': 1,
#  '감당': 2,
#  '감별': 1,
#  '감사': 5,
#  '감성': 1,
#  '감소': 115,
#  '감수': 2,
#  '감수성': 1,
#  '감시': 6,
#  '감안': 23,
#  '감액': 1,
#  '감염': 31,
#  '감염병': 5,
#  '감염증': 2,
#  '감지': 1,
#  '감축': 9,
#  '감치': 2,
#  '갑자기': 1,
#  '갑작스럽다': 1,
#  '값': 74,
#  '강': 5,
#  '강구': 2,
#  '강도': 3,
#  '강력': 16,
#  '강력하다': 7,
#  '강릉': 5,
#  '강릉시': 1,
#  '강사': 1,
#  '강세': 30,
#  '강수': 1,
#  '강수량': 2,
#  '강아지': 1,
#  '강요': 3,
#  '강우': 1,
#  '강원': 36,
#  '강원대학교': 2,
#  '강원도': 31,
#  '강의': 1,
#  '강인하다': 1,
#  '강정': 1,
#  '강정화': 1,
#  '강제': 1,
#  '강조': 58,
#  '강타': 2,
#  '강하다': 4,
#  '강행': 2,
#  '강화': 67,
#  '강화군': 3,
#  '강화도': 1,
#  '강화하다': 10,
#  '같다': 83,
#  '개': 72,
#  '개국': 3,
#  '개그우먼': 1,
#  '개년': 1,
#  '개념': 1,
#  '개다': 9,
#  '개도': 1,
#  '개량': 17,
#  '개막': 1,
#  '개막식': 1,
#  '개반': 1,
#  '개발': 17,
#  '개방': 2,
#  '개별': 3,
#  '개사': 1,
#  '개선': 33,
#  '개설': 2,
#  '개성': 1,
#  '개수': 1,
#  '개시': 4,
#  '개악': 1,
#  '개월': 40,
#  '개월내': 1,
#  '개월전': 3,
#  '개인': 4,
#  '개전': 1,
#  '개정': 18,
#  '개정안': 9,
#  '개조': 1,
#  '개척': 2,
#  '개체': 34,
#  '개최': 48,
#  '개폐': 1,
#  '개표': 1,
#  '개학': 2,
#  '개회': 1,
#  '객': 3,
#  '갱': 2,
#  '갱신': 3,
#  '거': 4,
#  '거기': 1,
#  '거나': 3,
#  '거듭': 5,
#  '거래': 8,
#  '거래소': 1,
#  '거래처': 1,
#  '거론': 1,
#  '거리': 14,
#  '거미줄': 1,
#  '거부': 1,
#  '거세지다': 1,
#  '거수': 1,
#  '거수기': 1,
#  '거액': 1,
#  '거의': 12,
#  '거점': 3,
#  '거주': 1,
#  '거주지': 1,
#  '거짓': 2,
#  '거치': 1,
#  '걱정': 4,
#  '건': 34,
#  '건강': 9,
#  '건강하다': 2,
#  '건국': 1,
#  '건립': 3,
#  '건만': 1,
#  '건물': 1,
#  '건설': 2,
#  '건수': 9,
#  '건안': 1,
#  '건의': 16,
#  '건조': 3,
#  '건조하다': 3,
#  '건초': 1,
#  '건축': 2,
#  '건축물': 1,
#  '건축법': 1,
#  '걸리다': 1,
#  '걸치다': 1,
#  '검': 30,
#  '검사': 54,
#  '검사관': 2,
#  '검색': 4,
#  '검역': 30,
#  '검정': 7,
#  '검진': 1,
#  '검토': 16,
#  '것': 165,
#  '것임': 1,
#  '게': 7,
#  '게다가': 2,
#  '게시': 1,
#  '게재': 1,
#  '겨냥': 1,
#  '겨우': 3,
#  '겨우내': 1,
#  '겨울': 14,
#  '겨울철': 10,
#  '격량': 1,
#  '격려': 3,
#  '격리': 2,
#  '격상': 5,
#  '격차': 4,
#  '견인': 2,
#  '견주': 6,
#  '견줄': 1,
#  '견줘': 39,
#  '견학': 1,
#  '결': 1,
#  '결과': 88,
#  '결과물': 2,
#  '결단': 2,
#  '결론': 1,
#  '결사': 1,
#  '결산': 2,
#  '결속': 1,
#  '결실': 1,
#  '결의': 5,
#  '결정': 20,
#  '결정구조': 1,
#  '결제': 2,
#  '결함': 1,
#  '겸': 1,
#  '겹': 7,
#  '겹친': 1,
#  '경': 19,
#  '경계': 10,
#  '경고': 8,
#  '경과': 2,
#  '경관': 1,
#  '경구': 1,
#  '경기': 57,
#  '경기도': 23,
#  '경남': 8,
#  '경락': 26,
#  '경로': 8,
#  '경매': 4,
#  '경미하다': 1,
#  '경보': 6,
#  '경보기': 1,
#  '경북': 16,
#  '경비': 1,
#  '경상대': 1,
#  '경상북도': 1,
#  '경색': 1,
#  '경신': 14,
#  '경연': 28,
#  '경영': 30,
#  '경영인': 2,
#  '경영학': 1,
#  '경우': 97,
#  '경이': 1,
#  '경자년': 1,
#  '경작': 1,
#  '경쟁': 9,
#  '경쟁력': 14,
#  '경쟁률': 1,
#  '경제': 67,
#  '경제부총리': 1,
#  '경제성장률': 1,
#  '경제학': 1,
#  '경제활동': 1,
#  '경주': 1,
#  '경직': 1,
#  '경진': 1,
#  '경청': 1,
#  '경축': 1,
#  '경품': 3,
#  '경향': 1,
#  '경험': 5,
#  '계': 30,
#  '계간': 1,
#  '계기': 9,
#  '계란': 6,
#  '계로': 1,
#  '계룡': 1,
#  '계류': 2,
#  '계발': 1,
#  '계산': 1,
#  '계속': 24,
#  '계수': 1,
#  '계약': 5,
#  '계열': 8,
#  '계절': 9,
#  '계층': 2,
#  '계통': 2,
#  '계해': 3,
#  '계획': 68,
#  '고': 73,
#  '고가': 8,
#  '고개': 1,
#  '고객': 1,
#  '고급': 3,
#  '고기': 4,
#  '고기압': 2,
#  '고도화': 4,
#  '고라': 1,
#  '고량': 9,
#  '고려': 32,
#  '고령': 1,
#  '고령화': 1,
#  '고로': 1,
#  '고립': 2,
#  '고맙다': 1,
#  '고민': 1,
#  '고봉': 1,
#  '고삐': 1,
#  '고사': 1,
#  '고생': 2,
#  '고성': 14,
#  '고성군': 6,
#  '고속도로': 3,
#  '고수': 2,
#  '고스': 1,
#  '고시': 9,
#  '고심': 1,
#  '고압': 1,
#  '고양': 7,
#  '고온': 2,
#  '고용': 8,
#  '고용노동부': 3,
#  '고유': 1,
#  '고자': 2,
#  '고작': 1,
#  '고전': 1,
#  '고정': 1,
#  '고조': 4,
#  '고지': 1,
#  '고지연': 1,
#  '고착': 2,
#  '고찰': 1,
#  '고충': 2,
#  '고취': 1,
#  '고통': 2,
#  '고하': 1,
#  '고해': 1,
#  '곡': 1,
#  '곡리': 1,
#  '곡물': 11,
#  '곤': 2,
#  '곤두박질': 1,
#  '곤란하다': 1,
#  '곤충': 2,
#  '곧': 1,
#  '곧바로': 2,
#  '골든타임': 1,
#  '골자': 4,
#  '곱창': 1,
#  '곳': 18,
#  '곳곳': 2,
#  '곳도': 1,
#  '공': 40,
#  '공간': 2,
#  '공감': 5,
#  '공개': 7,
#  '공격': 1,
#  '공고': 1,
#  '공공': 4,
#  '공교': 1,
#  '공급': 46,
#  '공급원': 2,
#  '공기': 4,
#  '공단': 2,
#  '공동': 13,
#  '공동체': 1,
#  '공략': 2,
#  '공로': 1,
#  '공모전': 2,
#  '공무원': 4,
#  '공백': 3,
#  '공복': 1,
#  '공사': 10,
#  '공세': 1,
#  '공수': 1,
#  '공식': 12,
#  '공약': 1,
#  '공영': 1,
#  '공용': 1,
#  '공유': 8,
#  '공익': 4,
#  '공장': 5,
#  '공적': 1,
#  '공정': 2,
#  '공정위': 1,
#  '공정하다': 2,
#  '공존': 2,
#  '공직자': 1,
#  '공통': 2,
#  '공통점': 1,
#  '공판': 1,
#  '공항': 3,
#  '공휴일': 3,
#  '과': 31,
#  '과거': 9,
#  '과도': 14,
#  '과밀': 1,
#  '과반': 1,
#  '과반수': 1,
#  '과부': 3,
#  '과시': 1,
#  '과실': 1,
#  '과언': 2,
#  '과잉': 5,
#  '과장': 9,
#  '과정': 14,
#  '과제': 13,
#  '과중': 1,
#  '과징금': 1,
#  '과태료': 14,
#  '과학': 3,
#  '곽형근': 1,
#  '관': 7,
#  '관건': 3,
#  '관계': 17,
#  '관계자': 45,
#  '관광': 1,
#  '관광객': 3,
#  '관내': 3,
#  '관련': 71,
#  '관리': 91,
#  '관리부장': 1,
#  '관리사': 1,
#  '관리원': 6,
#  '관리인': 1,
#  '관리자': 2,
#  '관리제': 1,
#  '관서': 2,
#  '관성': 1,
#  '관세': 11,
#  '관세청': 4,
#  '관심': 18,
#  '관원': 3,
#  '관점': 3,
#  '관제': 2,
#  '관찰': 2,
#  '관철': 2,
#  '관측': 31,
#  '관할': 4,
#  '광고': 5,
#  '광등': 1,
#  '광복절': 1,
#  '광역': 23,
#  '광열': 1,
#  '광장': 2,
#  '광주': 1,
#  '광천읍': 1,
#  '광치령': 1,
#  '광화문': 2,
#  '괴산': 1,
#  '교': 1,
#  '교대': 2,
#  '교량': 1,
#  '교류': 4,
#  '교배': 4,
#  '교수': 7,
#  '교양': 1,
#  '교역': 5,
#  '교육': 14,
#  '교육과정': 1,
#  '교차': 5,
#  '교체': 1,
#  '교통': 1,
#  '교훈': 1,
#  '구': 25,
#  '구간': 17,
#  '구결': 1,
#  '구내': 3,
#  '구내식당': 3,
#  '구동': 1,
#  '구매': 21,
#  '구매력': 1,
#  '구멍': 1,
#  '구분': 9,
#  '구비': 2,
#  '구서': 2,
#  '구성': 12,
#  '구성원': 2,
#  '구속': 1,
#  '구수': 1,
#  '구심': 2,
#  '구역': 3,
#  '구연산': 1,
#  '구의': 1,
#  '구이': 4,
#  '구입': 9,
#  '구제': 2,
#  '구제역': 43,
#  '구조': 7,
#  '구조조정': 1,
#  '구진': 1,
#  '구청': 1,
#  '구체': 1,
#  '구체화': 1,
#  '구축': 13,
#  '구충': 1,
#  '구토': 1,
#  '구해': 1,
#  '구현': 1,
#  '구호': 1,
#  '구획': 2,
#  '국': 11,
#  '국가': 51,
#  '국가대표': 1,
#  '국경': 10,
#  '국고': 1,
#  '국내': 91,
#  '국내선': 1,
#  '국내외': 3,
#  '국립': 6,
#  '국립공원': 2,
#  '국면': 1,
#  '국무조정실': 1,
#  '국무총리': 2,
#  '국민': 28,
#  '국방부': 2,
#  '국비': 1,
#  '국산': 12,
#  '국서': 1,
#  '국어': 1,
#  '국장': 3,
#  '국정': 2,
#  '국제': 25,
#  '국제공항': 2,
#  '국제노동기구': 1,
#  '국한': 1,
#  '국회': 14,
#  '군': 39,
#  '군구': 1,
#  '군납': 1,
#  '군내': 1,
#  '군내면': 1,
#  '군데': 1,
#  '군림': 1,
#  '군별': 1,
#  '군부': 2,
#  '군사': 1,
#  '군사독재': 1,
#  '군산': 1,
#  '군인': 1,
#  '굵직하다': 1,
#  '굽다': 1,
#  '굿': 1,
#  '궁금증': 1,
#  '권': 13,
#  '권고': 3,
#  '권내': 2,
#  '권역': 10,
#  '권역별': 4,
#  '권유': 1,
#  '권익': 3,
#  '권장': 1,
#  '권한': 1,
#  '궐기': 3,
#  '궤': 1,
#  '귀': 2,
#  '귀국': 2,
#  '귀띔': 1,
#  '귀엽다': 1,
#  '규격': 3,
#  '규명': 1,
#  '규모': 33,
#  '규정': 13,
#  '규제': 19,
#  '규칙': 4,
#  '규탄': 1,
#  '균': 1,
#  '균일하다': 1,
#  '그': 56,
#  '그간': 7,
#  '그것': 1,
#  '그나마': 1,
#  '그대로': 2,
#  '그동안': 29,
#  '그때': 1,
#  '그래프': 3,
#  '그랜드': 1,
#  '그렇다': 6,
#  '그룹': 1,
#  '그린': 2,
#  '그림자': 1,
#  '그물': 1,
#  '극': 2,
#  '극대': 1,
#  '극명하다': 1,
#  '극복': 8,
#  '극성': 1,
#  '극심하다': 5,
#  '극적': 4,
#  '극히': 1,
#  '근': 7,
#  '근거': 14,
#  '근로': 2,
#  '근로기준법': 4,
#  '근로시간': 2,
#  '근로자': 6,
#  '근무': 5,
#  '근본': 1,
#  '근소': 1,
#  '근심': 1,
#  '근절': 5,
#  '근접하다': 1,
#  '근처': 1,
#  '글': 1,
#  '글로벌': 2,
#  '금': 5,
#  '금겹살': 1,
#  '금광면': 1,
#  '금년': 21,
#  '금도': 1,
#  '금돈': 1,
#  '금리': 1,
#  '금번': 2,
#  '금액': 6,
#  '금요일': 3,
#  '금융투자': 1,
#  '금은': 8,
#  '금일': 2,
#  '금지': 124,
#  '금지법': 1,
#  '급': 13,
#  '급감': 10,
#  '급갑': 1,
#  '급격하다': 3,
#  '급등': 14,
#  '급락': 5,
#  '급량': 27,
#  '급변': 1,
#  '급부': 1,
#  '급비': 3,
#  '급상승': 1,
#  '급성': 2,
#  '급속': 1,
#  '급식': 17,
#  '급여': 10,
#  '급증': 30,
#  '긍정': 2,
#  '기': 29,
#  '기각': 1,
#  '기간': 68,
#  '기관': 21,
#  '기구': 10,
#  '기금': 3,
#  '기기': 2,
#  '기념': 2,
#  '기념품': 1,
#  '기능': 5,
#  '기다': 3,
#  '기대': 12,
#  '기대하다': 1,
#  '기도': 4,
#  '기득권': 1,
#  '기량': 1,
#  '기록': 91,
#  '기르다': 3,
#  '기름': 1,
#  '기미': 1,
#  '기반': 13,
#  '기법': 1,
#  '기병': 1,
#  '기보': 1,
#  '기본': 9,
#  '기본권': 2,
#  '기부': 1,
#  '기분': 1,
#  '기사': 116,
#  '기상': 2,
#  '기상이변': 1,
#  '기상청': 7,
#  '기세': 3,
#  '기술': 10,
#  '기습': 2,
#  '기승': 3,
#  '기억': 1,
#  '기업': 12,
#  '기업가': 1,
#  '기여': 12,
#  '기온': 10,
#  '기와': 2,
#  '기인': 3,
#  '기자': 4,
#  '기자간담회': 3,
#  '기자회견': 3,
#  '기적': 8,
#  '기적처럼': 1,
#  '기점': 5,
#  '기조': 4,
#  '기존': 39,
#  '기준': 96,
#  '기지개': 1,
#  '기지역': 1,
#  '기질': 2,
#  '기초': 2,
#  '기타': 8,
#  '기탁': 2,
#  '기프티콘': 1,
#  '기피': 4,
#  '기하': 2,
#  '기한': 3,
#  '기해': 2,
#  '기회': 5,
#  '기획': 9,
#  '기획재정부': 2,
#  '기획전': 6,
#  '기후': 2,
#  '긴급': 34,
#  '긴밀하다': 1,
#  '긴박하다': 1,
#  '긴장': 9,
#  '긴장감': 2,
#  '길': 8,
#  '길다': 2,
#  '길이': 1,
#  '김': 8,
#  '김대균': 2,
#  '김명': 1,
#  '김명규': 1,
#  '김밥': 1,
#  '김병훈': 1,
#  '김성원': 1,
#  '김성중': 1,
#  '김씨': 1,
#  '김영균': 1,
#  '김영록': 1,
#  '김영환': 1,
#  '김용철': 1,
#  '김유': 1,
#  '김윤서': 1,
#  '김은호': 1,
#  '김장': 4,
#  '김재우': 1,
#  '김정우': 1,
#  '김제': 1,
#  '김천': 2,
#  '김태경': 1,
#  '김태봉': 1,
#  '김태환': 5,
#  '김태흠': 1,
#  '김포': 13,
#  '김포시': 5,
#  '김해': 2,
#  '김해시': 1,
#  '김현': 3,
#  '김현구': 2,
#  '김현섭': 2,
#  '김현수': 9,
#  '김현중': 1,
#  '깊다': 3,
#  '깨끗하다': 2,
#  '꼼짝': 1,
#  '꼽았다': 1,
#  '꾸러미': 1,
#  '꾸준하다': 5,
#  '꿈쩍': 1,
#  '끈': 3,
#  '끈질기다': 1,
#  '끝': 4,
#  '끼': 2,
#  '끼리': 1,
#  '나': 7,
#  '나가야': 2,
#  '나관일': 1,
#  '나날이': 1,
#  '나눔': 5,
#  '나들이': 3,
#  '나라': 7,
#  '나름': 1,
#  '나머지': 11,
#  '나볼': 1,
#  '나서다': 4,
#  '나선': 4,
#  '나스': 1,
#  '나아지다': 2,
#  '나이지리아': 1,
#  '나중': 1,
#  '나타나다': 2,
#  '낙': 1,
#  '낙폭': 2,
#  '난국': 1,
#  '난방': 1,
#  '난색': 1,
#  '난이': 1,
#  '날': 46,
#  '날로': 2,
#  '날씨': 11,
#  '낡다': 1,
#  '남': 2,
#  '남다': 4,
#  '남단': 2,
#  '남동': 1,
#  '남동쪽': 1,
#  '남면': 2,
#  '남미': 2,
#  '남발': 1,
#  '남방': 2,
#  '남부': 12,
#  '남북': 2,
#  '남북관계': 1,
#  '남성': 1,
#  '남아': 3,
#  '남양주': 7,
#  '남용': 2,
#  '남진': 1,
#  '남짓': 1,
#  '남쪽': 11,
#  '남태헌': 1,
#  '남하': 16,
#  '남향': 1,
#  '납품': 3,
#  '낮': 10,
#  '낮다': 26,
#  '낮아지다': 7,
#  '낮추다': 1,
#  '낳을': 1,
#  '내': 78,
#  '내내': 6,
#  '내년': 30,
#  '내다': 1,
#  '내달': 9,
#  '내륙': 3,
#  '내부': 14,
#  '내외': 6,
#  '내용': 19,
#  '내의': 1,
#  '내장': 2,
#  '내접': 1,
#  '내해': 1,
#  '낼': 1,
#  '냄새': 5,
#  '냉동': 15,
#  '냉면': 1,
#  '냉방': 2,
#  '냉장': 16,
#  '너구리': 1,
#  '넉': 2,
#  '널': 2,
#  '널리': 3,
#  '넓어지다': 1,
#  '넘다': 2,
#  '넘어서다': 1,
#  '넣기': 1,
#  '네': 2,
#  '네덜란드': 8,
#  '네이버': 2,
#  '네트워크': 7,
#  '네팔': 1,
#  '넷째': 4,
#  '년': 115,
#  '년도': 7,
#  '년비': 26,
#  '년전': 60,
#  '노고': 1,
#  '노동': 3,
#  '노동부': 1,
#  '노동시간': 1,
#  '노동자': 3,
#  '노란색': 1,
#  '노력': 48,
#  '노리': 1,
#  '노산': 2,
#  '노선': 1,
#  '노수현': 1,
#  '노임': 1,
#  ...}

# %% [markdown]
# ## 가격 등락 비율 뉴스데이터와 맵핑

# %%
df_all=pd.DataFrame(embedding_list)

# %%
df_all.shape
# Out:
# (208, 1)

# %%
df_all
# Out:
#                                                      0
# 0    종돈 종돈 마리 종돈 마리 수입 최고 종개 협 종개 협 신규 종개 협 신규 종돈 장...
# 184  제 한 협회장 한 협회장 선거 개최 한 협회 회장 회장 하태식 지난 지난 지난 정기...
# 185  살 처분 살 처분 대신 살 처분 대신 방역 살 처분 대신 방역 수준 농가 살 처분 ...
# 186  상반기 상반기 국내 코 감염증 증가 정부 코 백신 코 백신 지원 코 백신 지원 제외...
# 187  출하 감소 가운데 가운데 가운데 값 두 달 연속 두 달 연속 기록 최근 최근 축산물...
# 188  중앙 사고 수습 본부 중앙 사고 수습 본부 김현수 중앙 사고 수습 본부 김현수 본부...
# 189  강원 강원 인제군 강원 인제군 소재 강원 인제군 소재 양돈 장서 강원 인제군 소재 ...
# 190  최근 최근 최근 값 예상 크게 크게 웃다 가운데 크게 웃다 가운데 향후 크게 웃다 ...
# 191  벨기에 산 벨기에 산 돼지고기 이 달 수입 재개 하반기 하반기 우려 하반기 우려 하...
# 192  축 산업 축 산업 특성 상 축 산업 특성 상 근로기준법 상 축 산업 특성 상 근로기...
# 193  탄소 중립 시대 적 과제 지금 가축 분뇨 가축 분뇨 가치 재 평가 재 평가 되다 수...
# 194                                               NULL
# 195  강원도 강원도 정선 강원도 정선 야생 강원도 정선 야생 멧돼지 ASF 남쪽 세력 또...
# 196  겨울철 겨울철 대비 겨울철 대비 ASF 구제역 구제역 등 구제역 등 가축 구제역 등...
# 197  한 혁신 센터 한 혁신 센터 평균 한 혁신 센터 평균 MSY 두르다 기록 양돈 양돈...
# 198  박영 범 박영 범 농림축산식품부 박영 범 농림축산식품부 차관 지난 지난 지난 강원도...
# 199  도축업 계 정부 정부 ASF 정부 ASF 권역 화 정부 ASF 권역 화 정책 정부 ...
# 200  한 한 시세 역대 역대 역대 역대 값 역대 값 중 역대 값 중 최고 역대 값 중 최...
# 201  정부 이 달 이 달 말 외국인 외국인 근로자 외국인 근로자 입국 정상화 지난 지난 ...
# 202  좌측 배병규 배병규 대 의원 회 배병규 대 의원 회 감사 배상 건 배상 건 대 의원...
# 203  양돈 장 양돈 장 관리사 외국인 외국인 근로자 외국인 근로자 숙소 고용노동부 관리사...
# 204  한 협회 정부 정부 전국 정부 전국 축산 농가 정부 전국 축산 농가 특별 정부 전국...
# 205  출하 두 수가 출하 두 수가 최고 최고 치르다 기록 또 올해 출하 두 수가 출하 두...
# 206  작년 작년 세계 작년 세계 주요 작년 세계 주요 돈육 작년 세계 주요 돈육 수 출국...
# 207  정부 포괄 적 점진 적 환태평양 경 제 동반 자 협정 CPTPP 가입 가입 추진 공...

# %%
df_price_new=df_price.iloc[1:209,4:]

# %%
df_price_new=df_price_new.reset_index(drop=True)

# %%
df_price_new.shape
# Out:
# (208, 2)

# %%
df=pd.merge(df_all, df_price_new, left_index=True, right_index=True, how='left')

# %%
df.to_excel('../data/최종_데이터셋.xlsx',index=False)

# %% [markdown]
# ### 가격 그래프 확인해보기

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 생성
x_labels = df_price['도축일']
y_values = df_price['경락단가']

# 그래프 크기 설정
plt.figure(figsize=(16,8))

# 막대 그래프 그리기
plt.plot(x_labels, y_values)


# 그래프 타이틀과 축 라벨 설정
plt.title('Bar graph with 181 x-axis labels')
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')

# 그래프 보여주기
plt.show()
