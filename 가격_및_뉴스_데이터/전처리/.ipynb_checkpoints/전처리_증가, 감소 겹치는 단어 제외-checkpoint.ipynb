# %%
import numpy as np

print(np.__version__)
# 1.21.6
# Out:
# 1.20.3
# C:\Users\jaemin\Anaconda3\envs\py38\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\jaemin\Anaconda3\envs\py38\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\jaemin\Anaconda3\envs\py38\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# !pip3 install numpy==1.20.3
# Out:
# Requirement already satisfied: numpy==1.20.3 in c:\users\jaemin\anaconda3\envs\py38\lib\site-packages (1.20.3)

# %%
import pandas as pd
import numpy as np
import sklearn as scikit_learn
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from konlpy.tag import Okt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import re
import urllib.request
import mecab
from tqdm import tqdm
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_price=pd.read_excel('../data/가격데이터_증감비교_라벨링.xlsx')

# %%
df_news_list=[]
for i in range(208):
    globals()['df_news_{}'.format(i)]=pd.read_excel('../WordCount/word_count_{}.xlsx'.format(i))
    df_news_list.append(globals()['df_news_{}'.format(i)])

# %%
# df_news_list=[]
# for i in range(208):
#     globals()['df_news_{}'.format(i)]=pd.read_csv('./stem/stem_list{}.txt'.format(i),encoding = "utf-8")
#     df_news_list.append(globals()['df_news_{}'.format(i)])

# %%
df_price
# Out:
#            도축일         경락단가      경락단가_평균  label
# 0   2018-01-07  3691.039572  3691.039572      0
# 1   2018-01-14  3743.336317  3743.336317      1
# 2   2018-01-21  3743.359986  3743.359986      1
# 3   2018-01-28  3835.679915  3835.679915      1
# 4   2018-02-04  4276.198330  4276.198330      1
# 5   2018-02-11  4724.707319  4724.707319      1
# 6   2018-02-18  4103.632481  4103.632481      2
# 7   2018-02-25  3794.280663  3794.280663      2
# 8   2018-03-04  4094.180790  4094.180790      1
# 9   2018-03-11  3868.237571  3868.237571      2
# 10  2018-03-18  3909.816732  3909.816732      1
# 11  2018-03-25  4082.829832  4082.829832      1
# 12  2018-04-01  4891.438604  4891.438604      1
# 13  2018-04-08  4556.969848  4556.969848      2
# 14  2018-04-15  4679.382135  4679.382135      1
# 15  2018-04-22  4565.383399  4565.383399      2
# 16  2018-04-29  4691.108509  4691.108509      1
# 17  2018-05-06  4825.690619  4825.690619      1
# 18  2018-05-13  4716.390009  4716.390009      2
# 19  2018-05-20  4610.202560  4610.202560      2
# 20  2018-05-27  4713.913917  4713.913917      1
# 21  2018-06-03  4958.166162  4958.166162      1
# 22  2018-06-10  5140.368216  5140.368216      1
# 23  2018-06-17  5246.781158  5246.781158      1
# 24  2018-06-24  5388.587094  5388.587094      1
# 25  2018-07-01  5385.374827  5385.374827      2
# 26  2018-07-08  5717.301100  5717.301100      1
# 27  2018-07-15  5675.691409  5675.691409      2
# 28  2018-07-22  5368.465772  5368.465772      2
# 29  2018-07-29  4643.145000  4643.145000      2
# 30  2018-08-05  4724.776109  4724.776109      1
# 31  2018-08-12  4865.141373  4865.141373      1
# 32  2018-08-19  5108.502712  5108.502712      1
# 33  2018-08-26  5127.459872  5127.459872      1
# 34  2018-09-02  5151.834615  5151.834615      1
# 35  2018-09-09  5145.573216  5145.573216      2
# 36  2018-09-16  5196.986662  5196.986662      1
# 37  2018-09-23  4433.795464  4433.795464      2
# 38  2018-09-30  4510.229039  4510.229039      1
# 39  2018-10-07  4171.304569  4171.304569      2
# 40  2018-10-14  3933.000432  3933.000432      2
# 205  [지난해, 삼겹, 전, 한, 하다, 이후, 증가, 가격, 재, 돈, 수입, 소비, ...      2
# 206  [두, MSY, 농가, 돈, 국내, 지난해, PSY, 별, 들, 비교, 성적, 전국...      2
# 207  [CPTPP, 가입, 화, 되다, 및, 국, 재, 전, 타임스, 구획, 과실, 하다...      2

# %%
data_1=data[data['label']==1]
data_2=data[data['label']==2]

# %%
data_1_list=data_1['news'].values.tolist()
data_2_list=data_2['news'].values.tolist()

# %%
vocab_1 = list(set(doc for day in data_1_list for doc in day))
vocab_2 = list(set(doc2 for day2 in data_2_list for doc2 in day2))

# %%
len(vocab_2)
# Out:
# 2940

# %%
# Out:
# [nan,
#  '협회',
#  nan,
#  '코미',
#  nan,
#  '농업인',
#  '차이점',
#  '이벤트',
#  '실감',
#  '김태환',
#  '돈사',
#  '강타',
#  '교양',
#  '강구',
#  '소매',
#  '이사회',
#  '불공정',
#  '주로',
#  '정도',
#  '벌써',
#  '준용',
#  '움직임',
#  '등심',
#  '승주',
#  '처벌',
#  '제작',
#  '오히려',
#  '폭등',
#  '간략',
#  '돈용',
#  '과',
#  '절음',
#  '여행지',
#  '전례',
#  '반전',
#  '필리핀',
#  '과밀',
#  '향',
#  '긴장',
#  '자리',
#  '비례',
#  '급락',
#  '용량',
#  '대형',
#  '보건',
#  '요구',
#  '황금돼지',
#  '유예',
#  '세계기상기구',
#  '매몰',
#  '경기도',
#  '늘다',
#  '편하다',
#  '가도',
#  '돈육',
#  '안성',
#  '직전',
#  '야구장',
#  '학계',
#  '비추다',
#  '추계',
#  '재차',
#  '맞춤',
#  '소유',
#  '곧바로',
#  '건강',
#  '전략',
#  '경이',
#  '차관',
#  '가가',
#  '시작',
#  '등록',
#  '서도',
#  '밍',
#  '충청',
#  '활성화',
#  '현',
#  '박광욱',
#  '대정읍',
#  '공존',
#  '일당',
#  '재해',
#  '동의',
#  '업무',
#  '기기',
#  '남양주',
#  '개선',
#  '급등',
#  '국내선',
#  '홍',
#  '항공기',
#  '편의',
#  '입산',
#  '상태',
#  '동식물',
#  'Animal',
#  '증감',
#  'MOU',
#  '북한',
#  '초동',
#  '수입량',
#  '세척',
#  '과잉',
#  '중도',
#  '본',
#  '김천',
#  '철퇴',
#  '탕원',
#  '비료',
#  '정책',
#  '보다',
#  '에린',
#  '백약',
#  '대기업',
#  '고시',
#  '균일하다',
#  '관서',
#  '추산',
#  '시급하다',
#  '억제',
#  '혼합',
#  '경쟁력',
#  '연보',
#  '종국',
#  '수직',
#  '정상화',
#  '대치',
#  '왕',
#  '번지',
#  '동해',
#  '물품',
#  '야외',
#  '국무조정실',
#  '낙폭',
#  '추후',
#  '노동자',
#  '소비',
#  '동물복지',
#  '쉽다',
#  '세제',
#  '순위',
#  '호로',
#  'O',
#  '미세먼지',
#  '위탁',
#  '법인',
#  '남',
#  '불안',
#  '펴다',
#  '역할',
#  '구해',
#  '역대',
#  '품목',
#  '주문진읍',
#  '소시지',
#  '금도',
#  '노후',
#  '제기',
#  '겹',
#  '동기',
#  '처가',
#  '춘천시',
#  '상품거래소',
#  '보상금',
#  '그래프',
#  '산정',
#  '영월',
#  '샛',
#  '이슈',
#  '병',
#  '양념',
#  '이탈리아',
#  '국립',
#  '버크셔',
#  '나라',
#  '담화',
#  '대방역',
#  '적',
#  '추다',
#  '여러',
#  '정말',
#  '환축',
#  '저해',
#  '부회장',
#  'PCR',
#  '찌개',
#  '반등',
#  '지면',
#  '정보',
#  '인원',
#  '영향',
#  '예능',
#  '밀집',
#  '오락가락',
#  '누적',
#  '관측',
#  '쌍',
#  '효능',
#  '금융투자',
#  '저작권',
#  '오름',
#  '상한',
#  '기점',
#  '동해안',
#  'PSY',
#  '겨울철',
#  '포스팅',
#  '카카오',
#  '횡단하',
#  '동안',
#  '대량',
#  '경직',
#  '답보',
#  '프로그램',
#  '액',
#  '김용철',
#  '유튜버',
#  '사진',
#  '콘테스트',
#  '일신상',
#  '할인',
#  '인하',
#  '접근',
#  '법화',
#  '센트',
#  '것',
#  '나서다',
#  '낮다',
#  '령',
#  '정체',
#  '불행',
#  '뿌리',
#  '경연',
#  '재개',
#  '속도',
#  '라면',
#  '첫째',
#  '지점',
#  '분할',
#  '대장',
#  '주다',
#  '사정',
#  '건축법',
#  '심하다',
#  '은퇴',
#  '온실효과',
#  '의뢰',
#  '전쟁',
#  '등',
#  '고정',
#  '홍혜걸',
#  '청소',
#  '임정은',
#  '지수',
#  '계',
#  '좀처럼',
#  '독일',
#  '용도',
#  '숙지',
#  '금리',
#  'RFID',
#  '협조',
#  '업',
#  '공단',
#  '작용',
#  '최재철',
#  '백만',
#  '고해',
#  '요령',
#  '길다',
#  '마카오',
#  '비처',
#  '토론회',
#  '마이너스',
#  '문턱',
#  '심사',
#  '양산',
#  '지방산',
#  '극심하다',
#  'NH',
#  '입증',
#  '하',
#  '가장',
#  '출하물량',
#  '자료',
#  '지대',
#  '형태',
#  '관광객',
#  'DB',
#  '전월',
#  '유래',
#  '돌이',
#  '보태',
#  '거',
#  '쌀',
#  '산자부',
#  '커지다',
#  '공정',
#  '설',
#  '고전',
#  '감염',
#  '압박',
#  '축',
#  '복당',
#  '각별',
#  '철원',
#  '경락',
#  '기존',
#  '유',
#  '잡육',
#  '당연하다',
#  '강',
#  '한눈',
#  '냉면',
#  '한층',
#  '증정',
#  '달러',
#  '단기',
#  '테트라',
#  '곡물',
#  '빈축',
#  '추적',
#  '유영철',
#  '혜택',
#  '배병규',
#  '회식',
#  '고작',
#  '질환',
#  '지금',
#  '화로',
#  '늘리다',
#  '매다',
#  '와이',
#  '양일간',
#  '이르다',
#  '신호탄',
#  '차등',
#  '상국',
#  '가열',
#  '저조하다',
#  '순수하다',
#  'for',
#  'EU',
#  '주의보',
#  '양적',
#  '경신',
#  '종자',
#  'KBS',
#  '요',
#  '과징금',
#  '배',
#  '장수',
#  '고려',
#  '알루미늄',
#  '저변',
#  '장치',
#  '기조',
#  '업도',
#  '충족',
#  '도움',
#  '보호',
#  '입장',
#  '노동',
#  '일지',
#  '중이',
#  '로써',
#  '건조하다',
#  '출근길',
#  '확률',
#  '칠레',
#  '불안하다',
#  '보도',
#  '컨설팅',
#  '처',
#  '도축업',
#  '먹방',
#  '들다',
#  '관세청',
#  '재',
#  '착용',
#  '누가',
#  '계룡',
#  '가늠',
#  '인하다',
#  '무더위',
#  '직접',
#  '급비',
#  '밀폐',
#  '변동',
#  '남태헌',
#  '선임',
#  '각심',
#  '사가',
#  '감치',
#  '고수',
#  '기질',
#  '소모',
#  '실효',
#  '열악하다',
#  '확산',
#  '높다',
#  '차례',
#  '폐업',
#  '강도',
#  '삼겹',
#  '스테이크',
#  '대책',
#  '군내면',
#  '신속하다',
#  '기르다',
#  '연중',
#  '장담',
#  '선행',
#  '국립공원',
#  '일반',
#  '어',
#  '부스',
#  '절식',
#  '농가',
#  '농촌진흥청',
#  '철회',
#  '극적',
#  '조정',
#  '국가',
#  '중립',
#  '패키지',
#  '투입',
#  '일환',
#  '다수',
#  '계기',
#  '군별',
#  '일원화',
#  '지키다',
#  '얇다',
#  '응답',
#  '확실하다',
#  '북단',
#  '적자',
#  '응원',
#  '힘',
#  '식생활',
#  '조영욱',
#  '고용',
#  '게',
#  '생물',
#  '차원',
#  '지부',
#  '뚜렷하다',
#  '동선',
#  '약',
#  '방안',
#  '에프',
#  '현대',
#  '마저',
#  '유럽',
#  '국회',
#  '간소화',
#  '만',
#  '선박',
#  '청평',
#  '이산화탄소',
#  '지도',
#  '계란',
#  '위',
#  '마찬가지',
#  '축적',
#  '요소',
#  '의장',
#  '중앙',
#  '다시',
#  '먼지',
#  '긴밀하다',
#  '이희영',
#  '턱걸이',
#  '불신',
#  '유례',
#  '전지',
#  '북도',
#  'SOP',
#  '산속',
#  '야생',
#  '소강',
#  '시세로',
#  '목심',
#  '단성면',
#  '지역별',
#  '각종',
#  '한',
#  '고개',
#  '박',
#  '비건',
#  '병행',
#  '전남도',
#  '막대',
#  '없다',
#  '부여',
#  '가동',
#  '불과하다',
#  '고양',
#  '행적',
#  '원',
#  '지출',
#  '추정',
#  '진작',
#  '개인',
#  '구간',
#  '걱정',
#  '류',
#  '수익',
#  '휴가',
#  '수급',
#  '자체',
#  '병원',
#  '별',
#  '민통선',
#  '필수',
#  '아르헨티나',
#  '금년',
#  '밑',
#  '선진국',
#  'WTO',
#  'ICT',
#  '염소고기',
#  '이개',
#  '급격하다',
#  '정지',
#  '라니냐',
#  '베트',
#  '오다',
#  '반면',
#  '다발',
#  '관',
#  '우려',
#  '유용',
#  '역학',
#  '소외',
#  '대비',
#  '홍천',
#  '원점',
#  '입성',
#  '키',
#  '출하',
#  '등락',
#  '증액',
#  '조금',
#  '사치',
#  '결제',
#  '잔반',
#  '셈',
#  '인식',
#  '물가',
#  '김현섭',
#  '전원',
#  '고기',
#  '추세',
#  '장점',
#  '포리',
#  '충주',
#  '월별',
#  '상쇄된',
#  '감액',
#  '이코노미스트',
#  '해외여행',
#  '극',
#  '일로',
#  '의학박사',
#  '지구',
#  '벌이',
#  'Control',
#  '한돈협',
#  '연장',
#  '현실',
#  '신사',
#  '동계올림픽',
#  '탐지견',
#  '서면',
#  '가족',
#  '먹기',
#  '고착',
#  '이영자',
#  '뒷받침',
#  '최근',
#  '재화',
#  '품종',
#  '안보',
#  '그림자',
#  '전문',
#  '부장',
#  '북부',
#  '캔',
#  '오른쪽',
#  '오감',
#  '강화하다',
#  '의적',
#  '현재',
#  '경우',
#  '학교',
#  '의원',
#  '근',
#  '사용',
#  '바로',
#  '이',
#  '뿐',
#  '진',
#  '주임',
#  '텔',
#  '수도권',
#  '더',
#  '수취',
#  '상호',
#  '통제',
#  'SP',
#  '유명하다',
#  '상세',
#  '검사',
#  '가뜩이나',
#  '부산',
#  '교',
#  '종돈장',
#  '불볕',
#  '바닥',
#  '패러다임',
#  '서식',
#  '간의',
#  '시험',
#  '가공업',
#  '유보',
#  '개막',
#  '성',
#  '중순',
#  '기승',
#  '차이다',
#  '생체',
#  '산',
#  '사무소',
#  '진짜',
#  '이량',
#  '지물',
#  '커뮤니케이션',
#  '시계열',
#  '소비자원',
#  '울타리',
#  '책임',
#  '영업정지',
#  '전',
#  '해보다',
#  '전북',
#  '간담',
#  '주된',
#  '라보',
#  '공장',
#  '좌지우지',
#  '도체',
#  '소독제',
#  '관할',
#  '당분간',
#  '달',
#  '시정',
#  '습도',
#  '정관',
#  '줄다',
#  '인근',
#  '사항',
#  '체감',
#  '어려움',
#  '하루',
#  '노출',
#  '행사',
#  '하락',
#  '해소',
#  '발굴',
#  '충분하다',
#  '김영록',
#  '절반',
#  '고령화',
#  '늘어나다',
#  '위험성',
#  '비책',
#  '불황',
#  '중수',
#  '측면',
#  '전달',
#  '합성',
#  '연기',
#  '대가',
#  '춘천',
#  '하량',
#  '공동',
#  '하절',
#  '회의',
#  'PRDC',
#  '월령',
#  '간문제',
#  '당부',
#  '경험',
#  '동부',
#  '신뢰구간',
#  '시중',
#  '한진해운',
#  '아낌없다',
#  '낮',
#  '시식',
#  '골자',
#  '적체',
#  '영월군',
#  '건의',
#  '일인',
#  '보궐선거',
#  '구이',
#  '누구',
#  '대응',
#  '돕기',
#  '티',
#  '부작용',
#  '도구로',
#  '위생',
#  '판매',
#  '귀국',
#  '중장',
#  '비비',
#  '인상',
#  '자르다',
#  '기업',
#  '편이',
#  '투자',
#  '도모',
#  '이마트',
#  '의치',
#  '공정위',
#  '여름철',
#  '법정',
#  '무',
#  '지난해',
#  '위임',
#  '로드맵',
#  '고스',
#  '평균',
#  '인용',
#  '촉각',
#  '권',
#  '항상',
#  '란',
#  '양허',
#  '평가',
#  '무선주파수',
#  '향상',
#  '선',
#  '생방송투데이',
#  '공사',
#  '임용',
#  '출국',
#  '스마트',
#  '금겹살',
#  '절실',
#  '공고',
#  '면담',
#  '예고',
#  '삭제',
#  '갈수록',
#  '미미하다',
#  '사건',
#  '청',
#  '지각',
#  'and',
#  '확립',
#  '해외',
#  '그린',
#  '수량',
#  '표준',
#  '삼월',
#  '적극',
#  '착시',
#  '인체',
#  '의사',
#  '통합',
#  '가결',
#  '아침',
#  '작',
#  '가치판단',
#  '개국',
#  '명의',
#  '현장',
#  '대의',
#  '고지연',
#  '얼마',
#  '수기',
#  '대체로',
#  '미흡',
#  '무효',
#  '훈제',
#  '폐사',
#  '닥치다',
#  '원활하다',
#  '탁금',
#  '연구원',
#  '치사',
#  '전조',
#  '옥천',
#  '설사',
#  '원용',
#  '식육',
#  '조직',
#  '인적',
#  '애로',
#  '고성',
#  '위부',
#  '인프라',
#  '확행',
#  '가수',
#  '축종',
#  '실장',
#  '협정',
#  '유입',
#  '폭풍',
#  '넘다',
#  '동월',
#  '진입',
#  '발표',
#  '몰다',
#  '율',
#  '애용',
#  '구심',
#  '전북도',
#  '극대',
#  '태원',
#  '때',
#  '집단',
#  '감당',
#  '과도',
#  '장기',
#  'F',
#  '우촌',
#  'PRRS',
#  '내용',
#  '모두',
#  '주도하다',
#  '치면',
#  '흉막',
#  '국민',
#  '수용',
#  '송',
#  '호텔',
#  '주체',
#  '폭',
#  '동방',
#  '원부',
#  '끈',
#  '주제',
#  '제시',
#  '남부',
#  '두수',
#  '도드람',
#  '않다',
#  '상의',
#  '풀',
#  '대인',
#  '구조조정',
#  '안성시',
#  '바꾸다',
#  '거론',
#  '합',
#  '더하다',
#  '실업률',
#  '식품의약품안전처',
#  '주문',
#  '촌',
#  '이동',
#  '마케팅',
#  '유통업',
#  '출연',
#  '엇',
#  '올바르다',
#  '동력',
#  '관세',
#  '조절',
#  '소규모',
#  '온',
#  '사퇴',
#  '다소',
#  '절',
#  '농수산',
#  '세균',
#  '약속',
#  '성능',
#  '비다',
#  '징후',
#  '세',
#  '날',
#  '정확하다',
#  '세대',
#  '다른',
#  '백신',
#  '현행',
#  '무섭다',
#  '경쟁',
#  '친환경',
#  '전염병',
#  '규모',
#  '북미',
#  '이대',
#  '재난',
#  '씩',
#  '가파르',
#  '식약처',
#  '우수',
#  '정저우',
#  '건축물',
#  '남북관계',
#  '부담',
#  '두께',
#  '지방',
#  '보이지',
#  '작성',
#  '증권사',
#  '접종',
#  '삽입',
#  '일상',
#  '영양사',
#  '구매',
#  '퇴보하다',
#  '혈청형',
#  '취지',
#  '쪽',
#  '일본',
#  '도',
#  '설치다',
#  '개발',
#  '아지',
#  '글',
#  '사무국',
#  '소식',
#  '농축',
#  '구수',
#  '캐나다',
#  '원료',
#  '무한리필',
#  '로부터',
#  '참가자',
#  '연합',
#  '보강',
#  '성률',
#  '봉착',
#  '예년',
#  '키로',
#  '인',
#  'APVS',
#  '매년',
#  '하향',
#  '두보',
#  '세금',
#  '참석자',
#  '목소리',
#  '최영길',
#  '심각',
#  '발단',
#  '과거',
#  '추진',
#  '오른',
#  '고',
#  '결정',
#  '자재',
#  '초반',
#  '책임지다',
#  '벽두',
#  '비',
#  '연령',
#  '회장',
#  '조합',
#  '상황',
#  '앞',
#  '미진',
#  '식당',
#  '산이',
#  '기념품',
#  '사각',
#  '제거',
#  '학회',
#  '직위',
#  '하나',
#  '환경과학',
#  '이동성',
#  '홍콩',
#  '위기',
#  '치가',
#  '뱅크',
#  '채널',
#  '농사',
#  '범수',
#  '햄',
#  '타깃',
#  '축협',
#  '이바지',
#  '덴마크',
#  '년도',
#  '탄탄하다',
#  '구분',
#  '고지',
#  '완화',
#  '상치',
#  '입',
#  ...]

# %%
X_data = data['news']
y_data = df_price['label']
print('본문의 개수: {}'.format(len(X_data)))
print('레이블의 개수: {}'.format(len(y_data)))
# Out:
# 본문의 개수: 208
# 레이블의 개수: 208

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2,shuffle=False)
# X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, random_state=0, stratify=y_data)

# %%
my_set = set(vocab_1) #집합set으로 변환
my_list = list(my_set) #list로 변환

# %%
X_train
# Out:
# 0      ['두', '돼지', '돈', '농가', '한', '출하', 'MSY', '종돈',...
# 1      ['돈', '지난해', '돼지', '가격', '한', '하다', '최근', '두수'...
# 2      ['돼지', '출하', '수입', '등', '경우', '최근', '일', '되다',...
# 3      ['돈', '한', '전', '육', '돼지', '지난해', '양돈', '농가', ...
# 4      ['증가', '돼지', '생산', '돈', '가격', '하다', '및', '최근',...
# 5      ['구제역', '발생', '돈', '육', '백신', '하다', '지난해', '이상...
# 6                                                  [nan]
# 7      ['농가', '성적', '목표', '자급', '률', '돈', '경우', '산', ...
# 8      ['돈', '양돈', '종돈', '국내', '모돈', '한', '생산', '등', ...
# 9      ['돼지', '가격', '대비', '것', '들', '로', '출하', '돈', '...
# 10     ['돈', '지난해', '한', '수입', '대비', '전', '들', '법화', ...
# 11     ['미국', '수입', '수출', '돼지', '육', '고용', '돈육', '률',...
# 12     ['국내', '외국인', '하다', '돼지', '노동자', '한', '돈', '등'...
# 13     ['돼지', '수입', '미국', '시장', '돈', '농가', '한', '하다',...
# 14     ['수입', '돼지', '돼지고기', '올해', '최근', '돈', '농가', '량...
# 15     ['한', '가격', '하다', '사료', '수입', '미국', 'FTA', '돈'...
# 16     ['돼지', '수입', '돼지고기', '육', '두수', '값', '사', '증가'...
# 17                                                 [nan]
# 18     ['돼지', '출하', '전', '두수', '역대', '재', '올해', '최고',...
# 19     ['한', '돈', '소비', '등', '전', '하다', '경우', '할인', '...
# 20     ['수입', '재', '개', '검역', '시행', '창고', '조사', '재고',...
# 21     ['돼지', '지난해', '전', '생산비', '재', '두', '가운데', '돈'...
# 22     ['가격', '삼겹살', '및', '한', '돈', '도매', '전', '외식', ...
# 23     ['대비', '전', '재', '일', '지난해', '현충일', '년', '양돈',...
# 24     ['배합사료', '들', '국제', '업체', '대두', '당', '가격', '사료...
# 25     ['한', '돈', '지난', '이후', '하락', '또한', '수입', '등급',...
# 26     ['전', '돼지', '대비', '년', '재', '동월', '올해', '출하', ...
# 27     ['한', '소비', '돈육', '등', '가정', '최근', '돈', '안주', ...
# 28     ['위해', '돈', '자', '및', '수급', '하반기', '안정', '재', ...
# 29     ['전', '대비', '일', '년', '농장', '각각', '년전', '재', '...
# 30                                                 [nan]
# 31     ['양돈', '돼지', '전', '일', '재', '경우', '하다', '폐', '...
# 32     ['돼지', '등외', '허난성', '및', '정저우', '출하', '경제', '등...
# 33     ['전', '재', '년', '가량', '시행', '수입', '창고', '검역', ...
# 34     ['열병', '아프리카', '돼지', '중국', '지난', 'ASF', '바이러스'...
# 35     ['한', '및', '돈', '돼지', '하반기', '내년', '상반기', '가격'...
# 118    ['고성군', '멧돼지', '건', '야생', '지난', '지역', '강원도', '...
# 119    ['도매시장', '물량', '출하', '전체', '가격', '올해', '등급', '...
# 120    ['돼지', '하다', '농장', '전', '두수', '개월', '재', '년', ...
# 121                                                [nan]
# 122    ['전', 'ASF', '재', '축산', '양돈', '농장', '차량', '타임스...
# 123    ['농가', 'ASF', '하다', '한', '돈', '피해', '들', '등', ...
# 124    ['농가', '돼지고기', 'ASF', '들', '최근', '및', '희생', '전...
# 125    ['ASF', '돼지', '가축', '발생', '당', '하다', '양돈', '전'...
# 126    ['대비', '평년', '하나', '년', '전', '동월', '돈', '한', '...
# 127    ['방역', '돼지', '되다', '발생', '이', '등', '최근', '지역',...
# 128    ['하반기', '돈', '한', '이후', '소비', '가격', '하다', '출하'...
# 129    ['한', '돈', '서문시장', '거리', '삼겹살', '조금', '및', '청주...
# 130    ['수출', '백신', '코로나', '약품', '동물', '이상', '인하다', '...
# 131    ['전', '대비', '년', '수입', '상반기', '재', '감소', '동월',...
# 132    ['등', '양돈', '지역', '장', 'ASF', '바이러스', '발생', '하...
# 133    ['ASF', '양돈', '방역', '포천시', '단지', '멧돼지', '들', '...
# 134                                                [nan]
# 135    ['돼지', '지난해', '전', '재', '되다', '년', '휴가', '양돈',...
# 136    ['수입', '돼지', '하다', '이', '장마', '양돈', '장', '돼지고기...
# 137    ['등', '방역', '가축', '농가', '피해', '질병', '발생', '되다'...
# 138    ['위해', '농장', '들', 'ASF', '양돈', '원산지', '지난', '농...
# 139    ['하다', '한', '돈', '적', '양돈', '산업', '종돈', '등', '...
# 140    ['전', '대비', '수입', '돼지고기', '년', '한', '감소', '동월'...
# 141    ['한', '돈', 'ASF', '등', '폴란드', '멧돼지', '지난', '다릿...
# 142    ['구제역', '백신', '전', '돼지', '양돈', '되다', '접종', '정국...
# 143    ['한', '및', '돈', '농장', '돼지', '방역', '등', '출하', '...
# 144    ['자돈', '종돈', '수입', '두', '및', '올해', '장', '수요', ...
# 145    ['양돈', 'ASF', '장', '되다', '농장', '방역', '첫', '발생'...
# 146    ['방역', '시', '군', '양돈', '개', '지역', '대해', '돼지', ...
# 147    ['들', '지역', '양돈', '농장', 'ASF', '농가', '방역', '전'...
# 148    ['사료', '전', '코로나', '재', '돼지', '등', '개', '년', '...
# 149    ['지역', '출하', '농장', '이동', '및', 'ASF', '모돈', '농가...
# 150    ['식', '농장', '양돈', '재입', '개', '돼지', '방역', '시설',...
# 151    ['돼지', '건', '식', '아프리카', '열병', '돈', '발생', '멧돼지...
# 152    ['ASF', '멧돼지', '광역', '방역', '개', '지점', '양돈', '및...
# 153    ['가격', '하다', '돼지', '한', '내년', '돈', '소비자', '재',...
# 154    ['야생', '축산', '멧돼지', '농가', 'ASF', '경영', '경북', '...
# 155    ['ASF', '멧돼지', '등', '야생', '광역', '양돈', '울타리', '...
# 156    ['양돈', '등', '지난', '재', '도', '만큼', '화재', '타임스',...
# 157    ['영월', '멧돼지', 'km', '방역', '야생', '검', '강원도', '강...
# 158    ['지역', 'ASF', '확산', '및', '강원도', '방역', '영월', '접...
# 159    ['발생', '권역', 'ASF', '방역', '지역', '및', '확산', '특성...
# 160    ['올해', '가격', '농가', '및', '돈', '한', '재', '대비', '...
# 161    ['ASF', '멧돼지', '화', '야생', '정부', '건', '돈', '권역'...
# 162    ['등', '및', '가격', '도축', '지난', '코로나', '수', '세', ...
# 163    ['방역', '지난', 'ASF', '한편', '멧돼지', '관리', '현재', '...
# 164    ['돼지', '재', '만큼', '환경', '통해', '질병', '돈사', '양돈'...
# 165    ['구제역', '및', '등', '분뇨', '경우', '연장', '재', '권역',...
# Name: news, dtype: object

# %%
print('훈련 샘플의 개수 :', len(X_train))
print('테스트 샘플의 개수 :', len(X_test))
# Out:
# 훈련 샘플의 개수 : 166
# 테스트 샘플의 개수 : 42

# %%
print('--------훈련 데이터의 비율-----------')
print(f'유지 = {round(y_train.value_counts()[0]/len(y_train) * 100,3)}%')
print(f'상승 = {round(y_train.value_counts()[1]/len(y_train) * 100,3)}%')
print(f'하락 = {round(y_train.value_counts()[2]/len(y_train) * 100,3)}%')
# Out:
# --------훈련 데이터의 비율-----------
# 유지 = 32.53%
# 상승 = 37.349%
# 하락 = 30.12%

# %%
print('--------테스트 데이터의 비율-----------')
print(f'유지 = {round(y_test.value_counts()[0]/len(y_test) * 100,3)}%')
print(f'상승 = {round(y_test.value_counts()[1]/len(y_test) * 100,3)}%')
print(f'하락 = {round(y_test.value_counts()[2]/len(y_test) * 100,3)}%')
# Out:
# --------테스트 데이터의 비율-----------
# 유지 = 19.048%
# 상승 = 50.0%
# 하락 = 30.952%

# %%
X_train.iloc[0]
# Out:
# "['두', '돼지', '돈', '농가', '한', '출하', 'MSY', '종돈', '이', '평균', '하락', '지난해', '수입', '증가', '사육', '환경', '물량', '두수', '장', '축산', '값', '최근', '연속', '전', '지난', '신규', '상반기', '사상', '들', '미만', '한돈팜스', '질병', '이후', '업체', '최고', '년', '양돈', '시', '작년', '육', '생산', '되다', '것', '농장', '기준', '내내', '식', '역시', '입', '일반', '화', '하다', '별로', '계열', '개선', '수가', '가격', '사', '사용', '대비', '약세', '또한', '수', '농', '경영', '종개', '변화', '별', '무허가', '장관', '모돈', '위해', '분석', '로', '지속', '비율', '악화', '그동안', '가축', '가운데', '가수', '통해', '기록', '이상', '비육', '달', '조사', '협', '주체', '법화', '이유', '이중', '예방', '개량', '호조', '관리', '시작', '노력', '가량', '기간', '적', '재화', '성적', '김', '전산', '크게', '암', '때', '강화', '이경수', '유지', '시설', '상', '새해', '영향', '연간', '적극', '세', '세다', '세로', '안전', '신년사', '식품', '연', 'AI', '전체', '축사', '대규모', '부처', '다만', '늘다', '통관', '농림축산식품부', '나선', '김영록', '표시', '국내', '국가', '관계', '곳', '허가', '현재', '경연', '협회', '후', 'kg', '대해', '원년', '직수입', '못', '많다', '마리', '중', '량', '보다', '또', '미국', '전환', '돼지고기', '동물복지', '모두', '종축', '전망', '해오다', '주요', '자료', '제도', '협의', '확보', '육성', '절반', '이하', '품종', '하량', '프랑스', '일', '최종', '적용
 1, 17, 244, 522, 11, 531, 39, 1135, 794, 465, 185, 116, 613, 478, 901, 115, 121, 59, 73, 37, 375, 76, 425, 106, 87, 355, 329, 4006, 266, 515, 38, 147, 56, 1246], [29, 248, 20, 336, 23, 81, 8, 13, 33, 3, 770, 1115, 6, 1264, 25, 35, 365, 50, 150, 3657, 921, 173, 2, 31, 267, 4, 290, 40, 17, 89, 577, 434, 306, 1179, 573, 1, 28, 867, 36, 305, 112, 1858, 1044, 1392, 3613, 361, 902, 14, 34, 968, 3696, 825, 360, 167, 570, 419, 61, 357, 1097, 55, 44, 196, 5, 2348, 83, 1964, 342, 263, 310, 78, 554, 1380, 191, 416, 45, 37, 3040, 182, 155, 108, 97, 71, 1758, 551, 389, 56, 1311, 257, 123, 160, 1124, 740, 206, 104, 147, 377, 208, 22, 38, 94, 571, 2536, 265, 234, 1955, 7, 515, 2111, 141, 74], [39, 16, 6, 4, 43, 32, 24, 23, 17, 1208, 3, 153, 8, 382, 33, 85, 303, 103, 30, 275, 35, 58, 29, 255, 243, 163, 634, 14, 59, 2, 733, 31, 199, 46, 94, 20, 181, 26, 461, 4608, 69, 138, 4395, 86, 36, 541, 225, 34, 355, 25, 28, 113, 654, 75, 247, 56, 551, 353, 124, 74, 110, 1850, 101, 178, 388, 10, 84, 478, 37, 324, 638, 131, 167, 119, 78, 5, 1, 691, 89, 160, 341, 147, 65, 18, 425, 3046, 22, 7, 12, 116, 38]]

# %%
word_to_index = tokenizer.word_index
vocab_size = len(word_to_index) + 1
print(vocab_size)
# Out:
# 4822

# %%
print('본문의 최대 길이 :',max(len(sent) for sent in X_train))
print('본문의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(sent) for sent in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 본문의 최대 길이 : 3421
# 본문의 평균 길이 : 1196.3855421686746

# %%
max_len = 3421

# %%
X_train_encoded = pad_sequences(X_train_encoded, maxlen=max_len)
X_test_encoded = pad_sequences(X_test_encoded, maxlen=max_len)

# %%
X_train_encoded.shape

# %%
X_test_encoded.shape

# %% [markdown]
# ## 모델링

# %%
X_train_encoded=[]
    
vect=CountVectorizer()
for i in range(len(X_train)):
    vect.fit_transform(X_train)
    X_train_encoded.append(vect.vocabulary_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[236], line 5
#       3 vect=CountVectorizer()
#       4 for i in range(len(X_train)):
# ----> 5     vect.fit_transform(X_train)
#       6     X_train_encoded.append(vect.vocabulary_)
#
# File ~\Anaconda3\envs\py38\lib\site-packages\sklearn\feature_extraction\text.py:1377, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1369             warnings.warn(
#    1370                 "Upper case characters found in"
#    1371                 " vocabulary while 'lowercase'"
#    1372                 " is True. These entries will not"
#    1373                 " be matched with any documents"
#    1374             )
#    1375             break
# -> 1377 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1379 if self.binary:
#    1380     X.data.fill(1)
#
# File ~\Anaconda3\envs\py38\lib\site-packages\sklearn\feature_extraction\text.py:1264, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1262 for doc in raw_documents:
#    1263     feature_counter = {}
# -> 1264     for feature in analyze(doc):
#    1265         try:
#    1266             feature_idx = vocabulary[feature]
#
# File ~\Anaconda3\envs\py38\lib\site-packages\sklearn\feature_extraction\text.py:111, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     109 else:
#     110     if preprocessor is not None:
# --> 111         doc = preprocessor(doc)
#     112     if tokenizer is not None:
#     113         doc = tokenizer(doc)
#
# File ~\Anaconda3\envs\py38\lib\site-packages\sklearn\feature_extraction\text.py:69, in _preprocess(doc, accent_function, lower)
#      50 """Chain together an optional series of text preprocessing steps to
#      51 apply to a document.
#      52
#    (...)
#      66     preprocessed string
#      67 """
#      68 if lower:
# ---> 69     doc = doc.lower()
#      70 if accent_function is not None:
#      71     doc = accent_function(doc)
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)
X_train_encoded = tokenizer.texts_to_sequences(X_train)
X_test_encoded = tokenizer.texts_to_sequences(X_test)
print(X_train_encoded[:5])
print(X_test_encoded[:5])

# %%
sample_list=['A','B','C']
sample_lower=[]
for i in range(len(sample_list)):
    sample_lower.append(sample_list[i].lower())
print(sample_lower)
# Out:
# ['a', 'b', 'c']

# %%
# 형태소 분석을 위한 함수

def tokenizer(text):
    okt = Okt()
    return okt.morphs(text)

# %%
def data_preprocessing():
    
    # 학습셋, 테스트셋 분리
    news_list2 = news_list
    price_list = df_price['label'].tolist()
    
    from sklearn.model_selection import train_test_split
    
    # 데이터의 80%는 학습셋, 20%는 테스트셋
    news_train, news_test, price_train, price_test = train_test_split(news_list2, price_list, test_size=0.2, random_state=0)
    
    return news_train, news_test, price_train, price_test

# %%
def learning(x_train, y_train, x_test, y_test):
    # 전처리가 끝난 데이터를 단어 사전으로 만들고
    # 리뷰별로 나오는 단어를 파악해서 수치화 (벡터화)해서 학습
    # tfidf, 로지스틱 회귀 이용
    
    tfidf = TfidfVectorizer(lowercase=False)
    # 로지스틱
    logistic = LogisticRegression(C=2, penalty='l2', random_state=0)     # C의 숫자가 너무 크면 과적합 (기본 1), penalty로 과적합 방지
    
    pipe = Pipeline([('vect',tfidf),('clf',logistic)])
    
    # 학습
    pipe.fit(x_train, y_train)
    
    # 학습 정확도 측정
    y_pred = pipe.predict(x_test)
    print(accuracy_score(y_test, y_pred))
    
    # 학습한 모델을 저장
    with open('pipe.dat', 'wb') as fp:     # 쓰기, 바탕화면에 저장됨
        pickle.dump(pipe, fp)
        
    print('저장완료')     # 학습된 모델 저장 완료

# %%
def using():
    # 객체를 복원, 저장된 모델 불러오기
    with open('pipe.dat','rb') as fp:     # 읽기
        pipe = pickle.load(fp)
        
    while True :
        text = input('뉴스 키워드를 입력해주세요 : ')     # 인풋
        
        str = [text]
        
        # 예측 정확도
        r1 = np.max(pipe.predict_proba(str)*100)     # 확률값을 구해서 *100..?
        
        # 예측 결과
        r2 = pipe.predict(str)[0]     # 긍정('1'), 부정('0')
        
        if r2 == '1':
            print('돼지고기 가격은 상승할 것으로 예상됩니다.')
        
        elif r2 == '0':
            print('돼지고기 가격은 유지될 것으로 예상됩니다.')
        else: 
            print('돼지고기 가격은 하락할 것으로 예상됩니다.')
            
        print('정확도 : %.3f' % r1)
        print('------------------------------------------------')

# %%
# 학습 함수

def model_learning():   # 감성분석 모델 생성
    news_train, news_test, price_train, price_test = data_preprocessing()
    learning(news_train, price_train, news_test, price_test)
    
# 사용 함수

def model_using():   # 감성분석 모델 사용
    using()

# %%
model_learning()
